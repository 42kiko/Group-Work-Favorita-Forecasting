# %% [markdown]
# # EDA

# %% [markdown]
# ## Data

# %% [markdown]
# ### Change DIR

# %%
import sys
from pathlib import Path

# Füge den src-Ordner zum Python-Pfad hinzu
sys.path.append(str(Path("..", "src")))

# %% [markdown]
# ### Imports

# %%
from Favorita_TSA.data_loader import parquet_loader

# %% [markdown]
# ### Data Overview

# %%
import os

# Überprüfe den aktuellen Arbeitsordner
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: c:\Users\Kiko\Desktop\Code\tutoring\Group-Work-Favorita-Forecasting\notebooks

# %%
import os

# Setze das Arbeitsverzeichnis auf das Hauptprojektverzeichnis
os.chdir("C:/Users/Kiko/Desktop/Code/tutoring/Group-Work-Favorita-Forecasting")

# Überprüfe, ob das Verzeichnis korrekt gesetzt wurde
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: C:\Users\Kiko\Desktop\Code\tutoring\Group-Work-Favorita-Forecasting

# %%
df_oil = parquet_loader("oil")
df_items = parquet_loader("items")
df_holidays = parquet_loader("holidays_events")
df_stores = parquet_loader("stores")
df_transactions = parquet_loader("transactions")
df_train = parquet_loader("train")

# %%
print(df_items.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4100 entries, 0 to 4099
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item_nbr    4100 non-null   int64
#  1   family      4100 non-null   object
#  2   class       4100 non-null   int64
#  3   perishable  4100 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 128.3+ KB
# None

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df_items, title="YData Profiling Report", explorative=True)

# %%
profile.to_file("your_report.html")
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 2666.86it/s]?, ?it/s, Describe variable: perishable]
# Summarize dataset: 100%|██████████| 17/17 [00:00<00:00, 72.50it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:00<00:00,  3.78it/s]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00, 49.91it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 498.97it/s]
