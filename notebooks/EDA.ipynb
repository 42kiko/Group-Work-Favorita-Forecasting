# %% [markdown]
# # EDA

# %% [markdown]
# ## Data

# %% [markdown]
# ### Change DIR

# %% [markdown]
# ### Imports

# %%
import pandas as pd

from Favorita_TSA.data_loader import parquet_loader
from Favorita_TSA.dataset import Dataset

# %% [markdown]
# ### Data Overview

# %%
import os
from pathlib import Path

print("Current working directory:", os.getcwd())

PROJECT_ROOT = Path("..").resolve()

# Setze das Arbeitsverzeichnis auf das Hauptprojektverzeichnis
os.chdir(f"{PROJECT_ROOT}")

# Überprüfe, ob das Verzeichnis korrekt gesetzt wurde
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/cristallagus/Desktop/GitHub/Group-Work-Favorita-Forecasting/notebooks
# Current working directory: /Users/cristallagus/Desktop/GitHub/Group-Work-Favorita-Forecasting

# %%
df_oil = parquet_loader(Dataset.OIL)
df_items = parquet_loader(Dataset.ITEMS)
df_holidays = parquet_loader(Dataset.HOLIDAYS_EVENTS)
df_stores = parquet_loader(Dataset.STORES)
df_transactions = parquet_loader(Dataset.TRANSACTIONS)
df_train = parquet_loader(Dataset.TRAIN)
# Out:
# BASE_DIR data/processed/train

# %%
print(df_items.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4100 entries, 0 to 4099
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item_nbr    4100 non-null   int64
#  1   family      4100 non-null   object
#  2   class       4100 non-null   int64
#  3   perishable  4100 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 128.3+ KB
# None

# %%
df_train
# Out:
#                   id       date  store_nbr  item_nbr  unit_sales  onpromotion
# 0                  0 2013-01-01         25    103665         7.0         <NA>
# 1                  1 2013-01-01         25    105574         1.0         <NA>
# 2                  2 2013-01-01         25    105575         2.0         <NA>
# 3                  3 2013-01-01         25    108079         1.0         <NA>
# 4                  4 2013-01-01         25    108701         1.0         <NA>
# ...              ...        ...        ...       ...         ...          ...
# 125497035  125497035 2017-08-15         54   2089339         4.0        False
# 125497036  125497036 2017-08-15         54   2106464         1.0         True
# 125497037  125497037 2017-08-15         54   2110456       192.0        False
# 125497038  125497038 2017-08-15         54   2113914       198.0         True
# 125497039  125497039 2017-08-15         54   2116416         2.0        False
#
# [125497040 rows x 6 columns]

# %%
df_train[df_train["unit_sales"] == 89440]
# Out:
#                 id       date  store_nbr  item_nbr  unit_sales  onpromotion
# 93189596  93189596 2016-10-07         39   1976284     89440.0        False

# %%
df_items[df_items["item_nbr"] == 1976284]
# Out:
#       item_nbr family  class  perishable
# 3434   1976284  MEATS   2302           1

# %%
df = pd.read_csv("./data/raw/train.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_csv("./data/raw/train.csv")
#
# File ~/Desktop/GitHub/Group-Work-Favorita-Forecasting/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df_holidays[df_holidays["locale"] == "Regional"]
# Out:
#            date     type    locale                     locale_name  \
# 1    2012-04-01  Holiday  Regional                        Cotopaxi
# 7    2012-06-25  Holiday  Regional                        Imbabura
# 23   2012-11-06  Holiday  Regional  Santo Domingo de los Tsachilas
# 24   2012-11-07  Holiday  Regional                     Santa Elena
# 47   2013-04-01  Holiday  Regional                        Cotopaxi
# 58   2013-06-25  Holiday  Regional                        Imbabura
# 76   2013-11-06  Holiday  Regional  Santo Domingo de los Tsachilas
# 77   2013-11-07  Holiday  Regional                     Santa Elena
# 96   2014-04-01  Holiday  Regional                        Cotopaxi
# 112  2014-06-25  Holiday  Regional                        Imbabura
# 139  2014-11-06  Holiday  Regional  Santo Domingo de los Tsachilas
# 140  2014-11-07  Holiday  Regional                     Santa Elena
# 165  2015-04-01  Holiday  Regional                        Cotopaxi
# ...

# %%
for element in Dataset:
    print(element, "\n", parquet_loader(element).head(), "\n")
# Out:
# Dataset.OIL
#           date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20
#
# Dataset.ITEMS
#     item_nbr        family  class  perishable
# 0     96995     GROCERY I   1093           0
# 1     99197     GROCERY I   1067           0
# 2    103501      CLEANING   3008           0
# 3    103520     GROCERY I   1028           0
# 4    103665  BREAD/BAKERY   2712           1
#
# Dataset.HOLIDAYS_EVENTS
#           date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
# ...

# %% [markdown]
# ## Join tables
#
# (df_train + df_stores + df_items + df_holiday + df_oil) mergen
#  - date
#  - store_nbr
#  - city
#  - state
#  - item_nbr
#  - family
#  - class
#  - perishable
#  - type
#  - locale
#  - dcoilwtico
#
# (df_transcation + df_stores) mergen
#  - date
#  - store_nbr
#  - transactions
#  - city
#  - state

# %%
df_merged = df_train.merge(df_stores, on="store_nbr", how="left")

# %%
display(df_merged)
# Out:
#                   id       date  store_nbr  item_nbr  unit_sales  onpromotion  \
# 0                  0 2013-01-01         25    103665         7.0         <NA>
# 1                  1 2013-01-01         25    105574         1.0         <NA>
# 2                  2 2013-01-01         25    105575         2.0         <NA>
# 3                  3 2013-01-01         25    108079         1.0         <NA>
# 4                  4 2013-01-01         25    108701         1.0         <NA>
# ...              ...        ...        ...       ...         ...          ...
# 125497035  125497035 2017-08-15         54   2089339         4.0        False
# 125497036  125497036 2017-08-15         54   2106464         1.0         True
# 125497037  125497037 2017-08-15         54   2110456       192.0        False
# 125497038  125497038 2017-08-15         54   2113914       198.0         True
# 125497039  125497039 2017-08-15         54   2116416         2.0        False
#
# ...

# %%
df_merged = df_merged.drop(columns=["type", "cluster"])

# %%
df_merged
# Out:
#                   id       date  store_nbr  item_nbr  unit_sales  onpromotion  \
# 0                  0 2013-01-01         25    103665         7.0         <NA>
# 1                  1 2013-01-01         25    105574         1.0         <NA>
# 2                  2 2013-01-01         25    105575         2.0         <NA>
# 3                  3 2013-01-01         25    108079         1.0         <NA>
# 4                  4 2013-01-01         25    108701         1.0         <NA>
# ...              ...        ...        ...       ...         ...          ...
# 125497035  125497035 2017-08-15         54   2089339         4.0        False
# 125497036  125497036 2017-08-15         54   2106464         1.0         True
# 125497037  125497037 2017-08-15         54   2110456       192.0        False
# 125497038  125497038 2017-08-15         54   2113914       198.0         True
# 125497039  125497039 2017-08-15         54   2116416         2.0        False
#
# ...

# %%
df_merged = df_merged.merge(df_items, on="item_nbr", how="left")

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125497040 entries, 0 to 125497039
# Data columns (total 11 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   date         datetime64[ns]
#  2   store_nbr    int16
#  3   item_nbr     int32
#  4   unit_sales   float64
#  5   onpromotion  boolean
#  6   city         object
#  7   state        object
#  8   family       object
#  9   class        int64
#  10  perishable   int64
# dtypes: boolean(1), datetime64[ns](1), float64(1), int16(1), int32(1), int64(3), object(3)
# memory usage: 8.4+ GB

# %%
df_holidays["date"] = df_holidays["date"].astype("datetime64[ns]")

# %%
df_merged = df_merged.merge(
    df_holidays,
    left_on=["date", "city"],
    right_on=["date", "locale_name"],
    how="left",
)

# %%
df_merged = df_merged.drop(columns=["locale_name", "description"])

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125509976 entries, 0 to 125509975
# Data columns (total 14 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   date         datetime64[ns]
#  2   store_nbr    int16
#  3   item_nbr     int32
#  4   unit_sales   float64
#  5   onpromotion  boolean
#  6   city         object
#  7   state        object
#  8   family       object
#  9   class        int64
#  10  perishable   int64
#  11  type         object
#  12  locale       object
#  13  transferred  object
# dtypes: boolean(1), datetime64[ns](1), float64(1), int16(1), int32(1), int64(3), object(6)
# memory usage: 11.2+ GB

# %%
df_oil["date"] = df_oil["date"].astype("datetime64[ns]")

# %%
df_merged = df_merged.merge(df_oil, on="date", how="left")

# %%
df_merged
# Out:
#                   id       date  store_nbr  item_nbr  unit_sales  onpromotion  \
# 0                  0 2013-01-01         25    103665         7.0         <NA>
# 1                  1 2013-01-01         25    105574         1.0         <NA>
# 2                  2 2013-01-01         25    105575         2.0         <NA>
# 3                  3 2013-01-01         25    108079         1.0         <NA>
# 4                  4 2013-01-01         25    108701         1.0         <NA>
# ...              ...        ...        ...       ...         ...          ...
# 125509971  125497035 2017-08-15         54   2089339         4.0        False
# 125509972  125497036 2017-08-15         54   2106464         1.0         True
# 125509973  125497037 2017-08-15         54   2110456       192.0        False
# 125509974  125497038 2017-08-15         54   2113914       198.0         True
# 125509975  125497039 2017-08-15         54   2116416         2.0        False
#
# ...

# %%
df_stores["city"].dropna().sort_values().unique()
# Out:
# array(['Ambato', 'Babahoyo', 'Cayambe', 'Cuenca', 'Daule', 'El Carmen',
#        'Esmeraldas', 'Guaranda', 'Guayaquil', 'Ibarra', 'Latacunga',
#        'Libertad', 'Loja', 'Machala', 'Manta', 'Playas', 'Puyo',
#        'Quevedo', 'Quito', 'Riobamba', 'Salinas', 'Santo Domingo'],
#       dtype=object)

# %%
df_holidays["locale_name"].dropna().sort_values().unique()
# Out:
# array(['Ambato', 'Cayambe', 'Cotopaxi', 'Cuenca', 'Ecuador', 'El Carmen',
#        'Esmeraldas', 'Guaranda', 'Guayaquil', 'Ibarra', 'Imbabura',
#        'Latacunga', 'Libertad', 'Loja', 'Machala', 'Manta', 'Puyo',
#        'Quevedo', 'Quito', 'Riobamba', 'Salinas', 'Santa Elena',
#        'Santo Domingo', 'Santo Domingo de los Tsachilas'], dtype=object)

# %% [markdown]
# Cotopaxi
# Imbabura
# Santo Domingo de los Tsachilas
# Santa Elena

# %%
df_holidays_national = df_holidays[df_holidays["locale"] == "National"]
df_holidays_national
# Out:
#           date        type    locale locale_name  \
# 14  2012-08-10     Holiday  National     Ecuador
# 19  2012-10-09     Holiday  National     Ecuador
# 20  2012-10-12    Transfer  National     Ecuador
# 21  2012-11-02     Holiday  National     Ecuador
# 22  2012-11-03     Holiday  National     Ecuador
# ..         ...         ...       ...         ...
# 345 2017-12-22  Additional  National     Ecuador
# 346 2017-12-23  Additional  National     Ecuador
# 347 2017-12-24  Additional  National     Ecuador
# 348 2017-12-25     Holiday  National     Ecuador
# 349 2017-12-26  Additional  National     Ecuador
#
#                              description  transferred
# 14         Primer Grito de Independencia        False
# 19            Independencia de Guayaquil         True
# 20   Traslado Independencia de Guayaquil        False
# 21                       Dia de Difuntos        False
# 22               Independencia de Cuenca        False
# ...

# %%
df_holidays_local = df_holidays[df_holidays["locale"] == "Local"]
df_holidays_local
# Out:
#           date        type locale locale_name                  description  \
# 0   2012-03-02     Holiday  Local       Manta           Fundacion de Manta
# 2   2012-04-12     Holiday  Local      Cuenca          Fundacion de Cuenca
# 3   2012-04-14     Holiday  Local    Libertad    Cantonizacion de Libertad
# 4   2012-04-21     Holiday  Local    Riobamba    Cantonizacion de Riobamba
# 5   2012-05-12     Holiday  Local        Puyo       Cantonizacion del Puyo
# ..         ...         ...    ...         ...                          ...
# 339 2017-12-05  Additional  Local       Quito         Fundacion de Quito-1
# 340 2017-12-06     Holiday  Local       Quito           Fundacion de Quito
# 341 2017-12-08     Holiday  Local        Loja            Fundacion de Loja
# 342 2017-12-08    Transfer  Local       Quito  Traslado Fundacion de Quito
# 344 2017-12-22     Holiday  Local     Salinas     Cantonizacion de Salinas
#
#      transferred
# 0          False
# 2          False
# ...

# %%
df_holidays_regional = df_holidays[df_holidays["locale"] == "Regional"]
df_holidays_regional
# Out:
#           date     type    locale                     locale_name  \
# 1   2012-04-01  Holiday  Regional                        Cotopaxi
# 7   2012-06-25  Holiday  Regional                        Imbabura
# 23  2012-11-06  Holiday  Regional  Santo Domingo de los Tsachilas
# 24  2012-11-07  Holiday  Regional                     Santa Elena
# 47  2013-04-01  Holiday  Regional                        Cotopaxi
# 58  2013-06-25  Holiday  Regional                        Imbabura
# 76  2013-11-06  Holiday  Regional  Santo Domingo de los Tsachilas
# 77  2013-11-07  Holiday  Regional                     Santa Elena
# 96  2014-04-01  Holiday  Regional                        Cotopaxi
# 112 2014-06-25  Holiday  Regional                        Imbabura
# 139 2014-11-06  Holiday  Regional  Santo Domingo de los Tsachilas
# 140 2014-11-07  Holiday  Regional                     Santa Elena
# 165 2015-04-01  Holiday  Regional                        Cotopaxi
# ...
